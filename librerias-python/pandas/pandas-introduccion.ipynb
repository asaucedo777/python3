# %%
import pandas as pd

# %%
# Crear series de datos con pandas
serie = pd.Series([1,2,3])
serie.name = 'mi serie'
serie
# Out:
# 0    1
# 1    2
# 2    3
# Name: mi serie, dtype: int64

# %%
# Crear dataframe a partir de un diccionario de datos
data = {
    "id": [1, 2, 3, 4, 5],
    "producto": ["Manzana", "Banana", "Naranja", "Pera", "Manzana"],
    "precio": [1.2, 0.8, 1.0, 1.5, 1.2],
    "cantidad": [5, 3, 4, 2, 6]
}
# Crear DataFrame de pandas
df_from_dict = pd.DataFrame(data)
df_from_dict.head()
# Out:
#    id producto  precio  cantidad
# 0   1  Manzana     1.2         5
# 1   2   Banana     0.8         3
# 2   3  Naranja     1.0         4
# 3   4     Pera     1.5         2
# 4   5  Manzana     1.2         6

# %%
# Lectura de ficheros csv desde el sistema de archivos
df = pd.read_csv('iris.csv', header=None)
headers=['longitud_sepalo','ancho_sepalo','longitud_petalo','ancho_petalo','clase']
df.columns=headers
df.head()
# Out:
#    longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo   clase
# 0              5.1           3.5              1.4           NaN  setosa
# 1              4.9           3.0              1.4           0.2  setosa
# 2              4.7           3.2              1.3           0.2  setosa
# 3              4.6           3.1              1.5           0.2  setosa
# 4              5.0           3.6              1.4           0.2  setosa

# %%
# Operaciones con dataframes pandas
df.filter(items=['longitud_sepalo', 'ancho_petalo'])
# Out:
#      longitud_sepalo  ancho_petalo
# 0                5.1           NaN
# 1                4.9           0.2
# 2                4.7           0.2
# 3                4.6           0.2
# 4                5.0           0.2
# ..               ...           ...
# 145              6.7           2.3
# 146              6.3           1.9
# 147              6.5           2.0
# 148              6.2           2.3
# 149              5.9           1.8
#
# [150 rows x 2 columns]

# %%
# contar
df['clase'].value_counts()
# Out:
# clase
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# ordenar
df.sort_index()
# Out:
#      longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo      clase
# 0                5.1           3.5              1.4           NaN     setosa
# 1                4.9           3.0              1.4           0.2     setosa
# 2                4.7           3.2              1.3           0.2     setosa
# 3                4.6           3.1              1.5           0.2     setosa
# 4                5.0           3.6              1.4           0.2     setosa
# ..               ...           ...              ...           ...        ...
# 145              6.7           3.0              5.2           2.3  virginica
# 146              6.3           2.5              5.0           1.9  virginica
# 147              6.5           3.0              5.2           2.0  virginica
# 148              6.2           3.4              5.4           2.3  virginica
# 149              5.9           3.0              5.1           1.8  virginica
#
# [150 rows x 5 columns]

# %%
# acceso a columnas
df[['longitud_sepalo']]
# Out:
#      longitud_sepalo
# 0                5.1
# 1                4.9
# 2                4.7
# 3                4.6
# 4                5.0
# ..               ...
# 145              6.7
# 146              6.3
# 147              6.5
# 148              6.2
# 149              5.9
#
# [150 rows x 1 columns]

# %%
# acceso filas y columnas
df.iloc[[3,148],[0,1,2]]
# Out:
#      longitud_sepalo  ancho_sepalo  longitud_petalo
# 3                4.6           3.1              1.5
# 148              6.2           3.4              5.4

# %%
# datos nulos
df.isna().sum()
# Out:
# longitud_sepalo    0
# ancho_sepalo       0
# longitud_petalo    0
# ancho_petalo       1
# clase              0
# dtype: int64

# %%
# plotear datos
df.plot()
# Out:
# <Axes: >
