# %%
import matplotlib.pyplot as plt

# %%
# plot a line
plt.plot([1,2,3,5,8])

# %%
# plot a histogram
plt.hist([1,1,2,3,3,3,4,5,5,5,5,5,6,6])
# Out:
# (array([2., 0., 1., 0., 3., 0., 1., 0., 5., 2.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)
