# %% [markdown]
# **SCALING AND NORMALIZATION**

# %% [markdown]
# #### SCALING

# %%
# original data
import numpy as np


scale, size = 4, 10000
generator = np.random.default_rng()
original_data = generator.exponential(scale, size)

# %%
# scaled data
import pandas as pd
from sklearn.preprocessing import minmax_scale


scaled_data = minmax_scale(pd.DataFrame(original_data))

# %%
# Plot
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title('Original')
sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title('Scaled')
plt.show()

# %% [markdown]
# #### NORMALIZATION

# %%
# normalization
from scipy import stats


normalized_data = stats.boxcox(original_data)
fig, ax = plt.subplots(1, 2, figsize=(20,5))
sns.histplot(original_data, ax=ax[0], kde=True, color='r')
ax[0].set_title('Original')
sns.histplot(normalized_data, ax=ax[1])
ax[1].set_title('Normalized')
# Out:
# Text(0.5, 1.0, 'Normalized')
